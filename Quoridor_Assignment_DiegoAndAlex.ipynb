# %% [markdown]
# # Assignment 2 - Game 1: Quoridor
#
# ## Instructions
#
# This is a **self-contained notebook** - everything you need is here!
#
# ### Quick Start
# 1. **Run all cells** up to Section 4 (this loads the game client)
# 2. **Implement your solver** in Section 5
# 3. **Update configuration** in Section 7
# 4. **Play the game** in Section 7
#
# ### What You Need To Do
# - Focus ONLY on implementing `my_agent()` function (Section 5)
#   - You can create various players, you'll be able to select your preferred one.
# - Everything else is provided for you!
#
# ### About Quoridor
# Quoridor is a 2-player abstract strategy game where:
# - Players start at opposite ends of a 9x9 board
# - Goal: Be the first to reach the opposite side
# - Each turn: Either move your pawn OR place a wall to block opponent
# - Each player has 10 walls to use during the game
# - Walls must not completely block any player from reaching their goal

# %% [markdown]
# ---
# ## Section 1: Setup
#
# **Run this cell (no changes needed)**

# %%
import requests
import json
import time
import random
from typing import List, Optional, Tuple, Any, Dict
from copy import deepcopy
from collections import deque

print("✅ Dependencies imported")

BASE_URL = 'https://ie-aireasoning-gr4r5bl6tq-ew.a.run.app'  # Your Cloud Run URL

print("✅ Configuration loaded")
# Out:
# ✅ Dependencies imported
# ✅ Configuration loaded

# %% [markdown]
# ---
# ## Section 2: Game Client Library
#
# **Run this cell (no changes needed)**
#
# This defines the game client that handles all server communication.

# %%
class GameClient:
    def __init__(self, base_url: str, token: str, debug: bool = False):
        self.base_url = base_url.rstrip('/')
        self.token = token
        self.debug = debug

    def _make_request(self, endpoint: str, params: dict, max_retries: int = 10) -> dict:
        params['TOKEN'] = self.token
        url = f'{self.base_url}{endpoint}'

        for attempt in range(max_retries):
            try:
                if self.debug:
                    print(f"[DEBUG] Request: {endpoint}")
                    print(f"[DEBUG] Params: {params}")

                response = requests.get(url, params=params, timeout=30)

                if self.debug:
                    print(f"[DEBUG] Response [{response.status_code}]: {response.text[:200]}")

                if response.status_code == 200:
                    if response.text:
                        try:
                            return response.json()
                        except (json.JSONDecodeError, ValueError) as e:
                            if self.debug:
                                print(f"[DEBUG] Non-JSON response: {response.text[:100]}")
                            return {}
                    return {}
                else:
                    print(f"⚠️  HTTP {response.status_code}: {response.text[:200]}")

            except requests.exceptions.Timeout:
                print(f"⚠️  Request timeout (attempt {attempt + 1}/{max_retries})")
            except requests.exceptions.RequestException as e:
                print(f"⚠️  Request error: {e} (attempt {attempt + 1}/{max_retries})")
            except Exception as e:
                print(f"⚠️  Unexpected error: {type(e).__name__}: {e} (attempt {attempt + 1}/{max_retries})")

            if attempt < max_retries - 1:
                time.sleep(1)

        raise Exception(f"Failed to connect to {endpoint} after {max_retries} attempts")

    def create_match(self, game_type: str, num_games: int, multiplayer: bool = False) -> str:
        response = self._make_request('/new-match', {
            'game-type': game_type,
            'num-games': str(num_games),
            'multi-player': 'True' if multiplayer else 'False'
        })

        if 'match-id' not in response:
            print(f"❌ Server response missing 'match-id'. Response: {response}")
            raise KeyError(f"Server response missing 'match-id'. Got: {response}")

        return response['match-id']

    def join_match(self, match_id: str) -> dict:
        response = self._make_request('/join-match', {
            'match-id': match_id
        })
        return response

    def get_game_state(self, match_id: str, game_index: int) -> dict:
        return self._make_request('/game-state-in-match', {
            'match-id': match_id,
            'game-index': str(game_index)
        })

    def get_match_state(self, match_id: str) -> dict:
        return self._make_request('/match-state', {
            'match-id': match_id
        })

    def make_move(self, match_id: str, player: str, move: Any) -> bool:
        move_str = move if isinstance(move, str) else json.dumps(move)

        self._make_request('/make-move-in-match', {
            'match-id': match_id,
            'player': player,
            'move': move_str
        })
        return True

print("✅ GameClient loaded")


def play_game(
    solver,
    base_url: str,
    token: str,
    game_type: str,
    game_class,
    multiplayer: bool = False,
    match_id: Optional[str] = None,
    num_games: int = 1,
    debug: bool = False,
    verbose: bool = True
) -> Tuple:
    client = GameClient(base_url, token, debug=debug)

    if match_id is None:
        if verbose:
            print(f"🎮 Creating new match: {num_games} x {game_type}")
        match_id = client.create_match(game_type, num_games, multiplayer)
        if verbose:
            print(f"   Match ID: {match_id}")

    if verbose:
        print(f"🔗 Joining match {match_id}...")
    match = client.join_match(match_id)
    player = match['player']
    num_games = match.get('num-games', num_games)
    if verbose:
        print(f"   You are player: {player}")

    game_state = client.get_game_state(match_id, 0)
    if game_state['status'] == 'waiting':
        if verbose:
            print("⏳ Waiting for opponent to join...")
        while game_state['status'] == 'waiting':
            time.sleep(2)
            game_state = client.get_game_state(match_id, 0)

    all_results = []
    wins = 0
    losses = 0
    draws = 0

    while True:
        match_state = client.get_match_state(match_id)
        if match_state['status'] != 'in_progress':
            break
        game_num = match_state['current-game-index']

        if verbose:
            print(f"\n{'='*50}")
            print(f"🎮 GAME {game_num + 1}/{num_games}")
            print(f"{'='*50}\n")

        # Get initial game state and check player assignment
        game_state = client.get_game_state(match_id, game_num)

        # Update player sign if it changed (randomized per game)
        if 'my-player' in game_state and game_state['my-player']:
            new_player = game_state['my-player']
            if new_player != player and verbose and game_num > 0:
                print(f"ℹ️  Player assignment changed: You are now Player {new_player}\n")
            player = new_player

        game = game_class(game_state['state'], game_state['status'], game_state['player'], player)

        move_count = 0
        while game_state['status'] != 'complete':
            game_state = client.get_game_state(match_id, game_num)
            player = game_state['my-player']
            if 'winner' in game_state:
                break

            game = game_class(game_state['state'], game_state['status'], game_state['player'], player)

            if game.is_terminal():
                break

            if verbose:
                game.print_board()

            if game.current_player == player:
                if verbose:
                    print(f"🤔 Your turn (Player {player})...")

                try:
                    move = solver(game)

                    if verbose:
                        if hasattr(move, '__iter__') and not isinstance(move, str):
                            if len(move) > 0 and move[0] == 'M':
                                print(f"   Moving pawn to ({move[1]}, {move[2]})")
                            elif len(move) > 0 and move[0] == 'W':
                                print(f"   Placing {move[3]} wall at ({move[1]}, {move[2]})")
                            else:
                                print(f"   Move: {move}")
                        else:
                            print(f"   Move: {move}")

                    client.make_move(match_id, player, move)
                    move_count += 1

                except Exception as e:
                    print(f"❌ Error in solver: {e}")
                    import traceback
                    traceback.print_exc()
                    all_results.append(('error', None))
                    break
            else:
                if verbose:
                    print(f"⏳ Waiting for opponent (Player {game.current_player})...")
                time.sleep(2)

        # game is already terminal from the loop above
        if verbose:
            game.print_board()
            print("=" * 40)

        winner = game_state['winner']
        if winner == '-':
            if verbose:
                print("🤝 Game ended in a DRAW!")
            result = 'draw'
            draws += 1
        elif winner == player:
            if verbose:
                print("🎉 You WON! Congratulations!")
            result = 'win'
            wins += 1
        else:
            if verbose:
                print("😞 You LOST. Better luck next time!")
            result = 'loss'
            losses += 1

        all_results.append((result, player, winner))

        if verbose and num_games > 1:
            print(f"\n📊 Current Record: {wins}W - {losses}L - {draws}D")
            print(f"   Games Remaining: {num_games - game_num - 1}\n")

    # Return results
    stats = {
        'wins': wins,
        'losses': losses,
        'draws': draws,
        'total_games': num_games,
        'win_rate': wins / num_games if num_games > 0 else 0,
        'player': player,
        'match_id': match_id
    }

    return stats, all_results

print("✅ play_game loaded")
# Out:
# ✅ GameClient loaded
# ✅ play_game loaded

# %% [markdown]
# ---
# ## Section 3: Game State Class & Helper Functions
#
# **Run this cell (no changes needed)**
#
# This defines the `QuoridorGame` class with all helper methods you'll need.

# %%
class QuoridorGame:
    """
    Represents Quoridor game state with helper methods.

    Key methods for your solver:
    - game.get_my_position()           # Your pawn position [row, col]
    - game.get_opponent_position()     # Opponent pawn position [row, col]
    - game.get_walls()                 # List of walls [[r, c, 'H'/'V'], ...]
    - game.get_remaining_walls()       # Your remaining wall count
    - game.get_valid_moves()           # All valid moves
    - game.get_valid_pawn_moves()      # Only pawn moves
    - game.get_valid_wall_moves()      # Only wall placements
    - game.simulate_move(move)         # Simulate move for search
    - game.is_terminal()               # Check if game over
    - game.print_board()               # Debug visualization
    """

    def __init__(self, state: str, status: str, current_player: str, my_player: str):
        self.state_str = state
        self.status = status
        self.current_player = current_player
        self.my_player = my_player
        self._state = None
        self._valid_moves = None

    @property
    def state(self) -> Dict:
        """Get state dictionary."""
        if self._state is None:
            self._state = json.loads(self.state_str)
        return self._state

    def get_my_position(self) -> List[int]:
        """Get your pawn position [row, col]."""
        return self.state['pawns'][self.my_player]

    def get_opponent_position(self) -> List[int]:
        """Get opponent pawn position [row, col]."""
        opp = '2' if self.my_player == '1' else '1'
        return self.state['pawns'][opp]

    def get_walls(self) -> List[List]:
        """Get list of walls [[row, col, 'H'/'V'], ...]."""
        return self.state['walls']

    def get_remaining_walls(self, player: Optional[str] = None) -> int:
        """Get remaining wall count for player (defaults to you)."""
        if player is None:
            player = self.my_player
        return self.state['remaining_walls'][player]

    def is_terminal(self) -> bool:
        """Check if game is over."""
        return self.status == 'complete'

    def is_waiting(self) -> bool:
        """Check if waiting for opponent."""
        return self.status == 'waiting'

    def get_winner(self) -> Optional[str]:
        """Get winner ('1', '2', None if ongoing)."""
        if not self.is_terminal():
            return None
        return self.current_player

    def get_opponent(self, player: str) -> str:
        """Get opponent's identifier."""
        return '2' if player == '1' else '1'

    def _is_wall_blocking(self, walls, from_pos, to_pos) -> bool:
        """Check if a wall blocks movement."""
        r1, c1 = from_pos
        r2, c2 = to_pos

        def has_wall(r, c, orient):
            return [r, c, orient] in walls

        # Moving up
        if r2 < r1 and c1 == c2:
            return has_wall(r2, c1, 'H') or has_wall(r2, c1 - 1, 'H')
        # Moving down
        elif r2 > r1 and c1 == c2:
            return has_wall(r1, c1, 'H') or has_wall(r1, c1 - 1, 'H')
        # Moving left
        elif c2 < c1 and r1 == r2:
            return has_wall(r1, c2, 'V') or has_wall(r1 - 1, c2, 'V')
        # Moving right
        elif c2 > c1 and r1 == r2:
            return has_wall(r1, c1, 'V') or has_wall(r1 - 1, c1, 'V')

        return False

    def _is_valid_pos(self, row, col) -> bool:
        """Check if position is within board bounds."""
        return 0 <= row < 9 and 0 <= col < 9

    def get_valid_pawn_moves(self, player: Optional[str] = None) -> List[List]:
        """Get valid pawn moves for player."""
        if player is None:
            player = self.current_player
        state = self.state
        my_pos = state['pawns'][player]
        opp_pos = state['pawns'][self.get_opponent(player)]
        walls = state['walls']
        r, c = my_pos
        moves = []

        # Basic adjacent moves
        adjacent = [(r - 1, c), (r + 1, c), (r, c - 1), (r, c + 1)]

        for new_r, new_c in adjacent:
            # Check bounds and wall blocking first
            if self._is_valid_pos(new_r, new_c) and not self._is_wall_blocking(walls, my_pos, [new_r, new_c]):
                if [new_r, new_c] == opp_pos:
                    # Try to jump over opponent
                    dr = new_r - r
                    dc = new_c - c
                    jump_r = new_r + dr
                    jump_c = new_c + dc

                    # Check if can jump straight
                    if self._is_valid_pos(jump_r, jump_c) and not self._is_wall_blocking(walls, opp_pos, [jump_r, jump_c]):
                        moves.append(['M', jump_r, jump_c])

                    else:
                        # Diagonal jumps when can't jump straight
                        if dr != 0:  # Moving vertically, try left/right
                            for side_dc in [-1, 1]:
                                side_c = new_c + side_dc
                                if self._is_valid_pos(new_r, side_c) and not self._is_wall_blocking(walls, opp_pos, [new_r, side_c]):
                                    moves.append(['M', new_r, side_c])

                        else:  # Moving horizontally, try up/down
                            for side_dr in [-1, 1]:
                                side_r = new_r + side_dr
                                if self._is_valid_pos(side_r, new_c) and not self._is_wall_blocking(walls, opp_pos, [side_r, new_c]):
                                    moves.append(['M', side_r, new_c])
                else:
                    # Normal move
                    moves.append(['M', new_r, new_c])

        return moves

    def get_valid_wall_moves(self, player: Optional[str] = None, limit: int = None) -> List[List]:
        """
        Get valid wall placements for player.

        Args:
            player: Player to get walls for (defaults to current player)
            limit: Maximum number of wall moves to return (for efficiency)
        """
        if player is None:
            player = self.current_player

        if self.get_remaining_walls(player) == 0:
            return []

        # NOTE: Checking all wall placements is expensive!
        # For performance, you may want to limit the number checked
        # or implement strategic wall placement heuristics

        moves = []
        walls = self.get_walls()

        # This is computationally expensive - consider limiting in your implementation
        # Try horizontal walls (simplified - only checks some positions)
        if limit:
            # Sample some random positions instead of checking all
            positions = [(r, c) for r in range(9) for c in range(8)]
            random.shuffle(positions)
            positions = positions[:limit]

            for r, c in positions:
                if self._is_valid_wall_simple([r, c, 'H'], walls):
                    moves.append(['W', r, c, 'H'])

            positions = [(r, c) for r in range(8) for c in range(9)]
            random.shuffle(positions)
            positions = positions[:limit]

            for r, c in positions:
                if self._is_valid_wall_simple([r, c, 'V'], walls):
                    moves.append(['W', r, c, 'V'])
        else:
            # Check all positions (slow!)
            for r in range(9):
                for c in range(8):
                    if self._is_valid_wall_simple([r, c, 'H'], walls):
                        moves.append(['W', r, c, 'H'])

            for r in range(8):
                for c in range(9):
                    if self._is_valid_wall_simple([r, c, 'V'], walls):
                        moves.append(['W', r, c, 'V'])

        return moves

    def _is_valid_wall_simple(self, wall, existing_walls) -> bool:
        """Simplified wall validation (doesn't check pathfinding)."""
        r, c, orient = wall

        # Check if wall already exists
        if wall in existing_walls:
            return False

        # Check for overlaps and crossings (simplified)
        if orient == 'H':
            if [r, c + 1, 'H'] in existing_walls or [r, c - 1, 'H'] in existing_walls:
                return False
            if [r - 1, c, 'V'] in existing_walls or [r, c, 'V'] in existing_walls:
                return False
            if [r - 1, c + 1, 'V'] in existing_walls or [r, c + 1, 'V'] in existing_walls:
                return False
        else:  # 'V'
            if [r + 1, c, 'V'] in existing_walls or [r - 1, c, 'V'] in existing_walls:
                return False
            if [r, c - 1, 'H'] in existing_walls or [r, c, 'H'] in existing_walls:
                return False
            if [r + 1, c - 1, 'H'] in existing_walls or [r + 1, c, 'H'] in existing_walls:
                return False

        # NOTE: This doesn't check if wall blocks all paths!
        # The server will reject invalid walls, but checking here is expensive
        return True

    def get_valid_moves(self, player: Optional[str] = None, limit_walls: int = 20) -> List[List]:
        """
        Get all valid moves.

        Args:
            player: Player to get moves for
            limit_walls: Limit wall checks for performance (set to None for all)
        """
        if self._valid_moves is None or player != self.current_player:
            pawn_moves = self.get_valid_pawn_moves(player)
            wall_moves = self.get_valid_wall_moves(player, limit=limit_walls)
            self._valid_moves = pawn_moves + wall_moves
        return self._valid_moves

    def simulate_move(self, move: List) -> Dict:
        """
        Simulate a move and return new state.
        Does NOT contact server or modify original state.
        Essential for minimax/alpha-beta, but this can be expensive because of deepcopy.
        """
        new_state = deepcopy(self.state)
        player = self.current_player

        if move[0] == 'M':
            # Pawn move
            new_state['pawns'][player] = [move[1], move[2]]
        elif move[0] == 'W':
            # Wall placement
            new_state['walls'].append([move[1], move[2], move[3]])
            new_state['remaining_walls'][player] -= 1

        return new_state

    def shortest_path_length(self, player: Optional[str] = None, state: Optional[Dict] = None) -> int:
        """
        Calculate shortest path length to goal using BFS.
        Useful for evaluation functions!

        Returns:
            int: Number of moves to goal, or 999 if no path
        """
        if player is None:
            player = self.my_player
        if state is None:
            state = self.state

        start = tuple(state['pawns'][player])
        goal_row = 8 if player == '1' else 0
        walls = state['walls']

        visited = {start: 0}
        queue = deque([start])

        while queue:
            r, c = queue.popleft()
            dist = visited[(r, c)]

            if r == goal_row:
                return dist

            for new_r, new_c in [(r-1, c), (r+1, c), (r, c-1), (r, c+1)]:
                if 0 <= new_r < 9 and 0 <= new_c < 9:
                    if (new_r, new_c) not in visited:
                        if not self._is_wall_blocking(walls, [r, c], [new_r, new_c]):
                            visited[(new_r, new_c)] = dist + 1
                            queue.append((new_r, new_c))

        return 999  # No path found

    def print_board(self):
        """Print nice board visualization."""
        state = self.state
        pawns = state['pawns']
        walls = state['walls']

        print("\n" + "=" * 37)
        print(f"Player 1: {pawns['1']}  Player 2: {pawns['2']}")
        print(f"Walls remaining - You: {self.get_remaining_walls(self.my_player)}, " +
              f"Opponent: {self.get_remaining_walls(self.get_opponent(self.my_player))}")
        print("=" * 37)

        # Create visual board
        for r in range(9):
            # Print row with cells
            row_str = ""
            for c in range(9):
                if pawns['1'] == [r, c]:
                    row_str += "1"
                elif pawns['2'] == [r, c]:
                    row_str += "2"
                else:
                    row_str += "·"

                # Check for vertical wall to the right
                if c < 8:
                    if [r, c, 'V'] in walls or (r > 0 and [r - 1, c, 'V'] in walls):
                        row_str += " ║ "
                    else:
                        row_str += "   "

            print(row_str)

            # Print horizontal walls
            if r < 8:
                wall_str = ""
                for c in range(9):
                    if [r, c, 'H'] in walls or (c > 0 and [r, c - 1, 'H'] in walls):
                        wall_str += "═"
                    else:
                        wall_str += " "

                    if c < 8:
                        wall_str += "   "

                print(wall_str)

        print("=" * 37 + "\n")

# %% [markdown]
# ---
# ## Section 4: Manual Play Mode (Try the Game Yourself!)
#
# **Play Quoridor manually** to understand the game before implementing your AI!
#
# This lets you:
# - Experience the game firsthand
# - Test the server connection
# - Understand winning strategies
# - Play against the server AI

# %%
def manual_player_solver(game: QuoridorGame) -> List:
    """
    Interactive manual player - YOU choose the moves!
    Perfect for testing the game and understanding the rules.
    """
    game.print_board()

    pawn_moves = game.get_valid_pawn_moves()
    wall_moves = game.get_valid_wall_moves(limit=30)

    print(f"\n🎮 YOUR TURN (Player {game.my_player})!")
    print("\nValid pawn moves:")
    for i, move in enumerate(pawn_moves):
        print(f"  {i}: Move to ({move[1]}, {move[2]})")

    if wall_moves and game.get_remaining_walls() > 0:
        print(f"\nOr place a wall (you have {game.get_remaining_walls()} left):")
        print("  Enter: W row col H/V (e.g., 'W 3 4 H')")

    while True:
        try:
            choice = input("\nEnter your choice (number for pawn move, or 'W r c H/V' for wall): ").strip()

            if choice.lower() == 'q':
                raise KeyboardInterrupt()

            if choice.upper().startswith('W'):
                parts = choice.split()
                if len(parts) == 4:
                    move = ['W', int(parts[1]), int(parts[2]), parts[3].upper()]
                    return move
                else:
                    print("❌ Invalid format! Use: W row col H/V")
            else:
                idx = int(choice)
                if 0 <= idx < len(pawn_moves):
                    return pawn_moves[idx]
                else:
                    print(f"❌ Invalid index! Choose 0-{len(pawn_moves)-1}")

        except ValueError:
            print("❌ Invalid input! Enter a number or 'W row col H/V'")
        except KeyboardInterrupt:
            print("\n👋 Thanks for playing!")
            raise

print("✅ Manual player loaded")
print("   Run the cell below to play interactively!")
# Out:
# ✅ Manual player loaded
#    Run the cell below to play interactively!

# %% [markdown]
# ---
# ## Section 5: YOUR SOLVER IMPLEMENTATION
#
# **⭐ THIS IS WHERE YOU WRITE YOUR CODE! ⭐**
#
# Implement your AI algorithm here. You can use:
# - Minimax
# - Alpha-beta pruning
# - Custom heuristics
# - A* pathfinding
#
# ### Available Methods
#
# ```python
# game.get_my_position()                    # Your pawn [row, col]
# game.get_opponent_position()              # Opponent pawn [row, col]
# game.get_walls()                          # List of walls
# game.get_remaining_walls(player)          # Wall count
# game.get_valid_moves()                    # All valid moves
# game.get_valid_pawn_moves()               # Only pawn moves
# game.get_valid_wall_moves(limit=20)       # Only walls (limited for speed)
# game.simulate_move(move)                  # Simulate move, returns new state
# game.shortest_path_length(player, state)  # BFS path length to goal
# game.print_board()                        # Print board
# ```
#
# ### Move Format
# - Pawn move: `['M', row, col]`
# - Wall placement: `['W', row, col, 'H']` or `['W', row, col, 'V']`
#
# ### Strategy Tips
# 1. Use `shortest_path_length()` in your evaluation function
# 2. Balance pawn advancement vs. blocking opponent with walls
# 3. Be careful with wall placement - checking all positions is slow!
# 4. Consider limiting search depth due to high branching factor

# %%
def my_agent(game: QuoridorGame) -> List:
    """
    Quoridor AI agent:
    - Greedy + depth-2 minimax
    - Wall simulation with path-length and backtracking heuristics
    - Extra "defense trap" mode when opponent is close to their goal
    - Tiny Monte Carlo tiebreak between top moves
    """

    my_player = game.my_player
    opp_player = game.get_opponent(my_player)

    state_now = game.state
    my_dist_now = game.shortest_path_length(my_player, state_now)
    opp_dist_now = game.shortest_path_length(opp_player, state_now)
    my_walls_now = state_now['remaining_walls'][my_player]
    opp_walls_now = state_now['remaining_walls'][opp_player]

    # ---------- Helpers: goal + base eval ----------

    def is_goal(state_dict: Dict, player: str) -> bool:
        r, c = state_dict['pawns'][player]
        goal_row = 8 if player == '1' else 0
        return r == goal_row

    def base_eval_state(state_dict: Dict) -> float:
        """Race + wall advantage evaluation (no move-specific tweaks)."""
        my_d = game.shortest_path_length(my_player, state_dict)
        opp_d = game.shortest_path_length(opp_player, state_dict)
        my_w = state_dict['remaining_walls'][my_player]
        opp_w = state_dict['remaining_walls'][opp_player]

        # Dead states
        if my_d >= 999 and opp_d >= 999:
            return -1e6
        if my_d >= 999:
            return -1e6
        if opp_d >= 999:
            return 1e6

        # Instant wins/losses
        if my_d == 0 and opp_d > 0:
            return 1e6
        if opp_d == 0 and my_d > 0:
            return -1e6

        race_term = 6.0 * (opp_d - my_d)          # main factor
        wall_term = 0.6 * (my_w - opp_w)          # mild wall advantage

        sprint_bonus = 0.0
        if my_d <= 3:
            sprint_bonus += 3.0
            if my_d < opp_d:
                sprint_bonus += 2.0

        # Opp wall-spam: they used many more walls than us -> racing is better
        wall_spam_bonus = 0.0
        if opp_w + 3 <= my_w:
            wall_spam_bonus += 1.5

        noise = random.uniform(-0.15, 0.15)

        return race_term + wall_term + sprint_bonus + wall_spam_bonus + noise

    # ---------- Helper: shortest path with explicit path (for backtracking) ----------

    def shortest_path_with_route(state_dict: Dict, player: str) -> Tuple[int, List[Tuple[int, int]]]:
        """
        BFS to compute shortest path length and one concrete path.
        Uses the same wall logic as shortest_path_length.
        """
        start = tuple(state_dict['pawns'][player])
        goal_row = 8 if player == '1' else 0
        walls = state_dict['walls']

        queue = deque([start])
        visited = {start: 0}
        parent: Dict[Tuple[int, int], Optional[Tuple[int, int]]] = {start: None}

        while queue:
            r, c = queue.popleft()
            dist = visited[(r, c)]

            if r == goal_row:
                # reconstruct path
                path = []
                cur = (r, c)
                while cur is not None:
                    path.append(cur)
                    cur = parent[cur]
                path.reverse()
                return dist, path

            for nr, nc in [(r-1, c), (r+1, c), (r, c-1), (r, c+1)]:
                if 0 <= nr < 9 and 0 <= nc < 9:
                    if (nr, nc) not in visited:
                        if not game._is_wall_blocking(walls, [r, c], [nr, nc]):
                            visited[(nr, nc)] = dist + 1
                            parent[(nr, nc)] = (r, c)
                            queue.append((nr, nc))

        return 999, []

    # Precompute opponent path in current state
    opp_dist_now_full, opp_path_now = shortest_path_with_route(state_now, opp_player)

    # DEFENSE ZONE: opponent within last 3 ranks of *their* goal (i.e. about to win on your side)
    opp_row_now, _ = state_now['pawns'][opp_player]
    opp_goal_row = 8 if opp_player == '1' else 0
    opp_dist_rows_to_goal = abs(opp_goal_row - opp_row_now)
    DEFENSE_ZONE = (0 < opp_dist_rows_to_goal <= 3 and my_walls_now > 0)

    # ---------- Move-specific scoring (1-ply) ----------

    def score_move_one_ply(move: List, new_state: Dict) -> float:
        """
        Score a move with:
        - base_eval_state(new_state)
        - plus pawn/wall specific heuristics
        - including backtracking bonus for walls
        - extra defense-mode behavior when opponent is near goal
        """
        base = base_eval_state(new_state)

        my_d_new = game.shortest_path_length(my_player, new_state)
        opp_d_new = game.shortest_path_length(opp_player, new_state)
        my_w_new = new_state['remaining_walls'][my_player]
        opp_w_new = new_state['remaining_walls'][opp_player]

        delta_my = my_d_new - my_dist_now
        delta_opp = opp_d_new - opp_dist_now

        if move[0] == 'M':
            # Reward progress along our shortest path
            if my_d_new < my_dist_now:
                base += 1.2

            # Sprint mode: heavy push to just finish
            if my_dist_now <= 3:
                # But if opponent is in DEFENSE_ZONE and we don't win immediately,
                # pure sprint is a bit less important than blocking.
                if DEFENSE_ZONE and not is_goal(new_state, my_player):
                    base += 1.0
                else:
                    base += 3.0

            # If opponent is low on walls, straight race is good
            if opp_w_new <= 3 and my_d_new <= opp_d_new:
                base += 1.0

            # In DEFENSE_ZONE, slightly penalize "just walking" if we still have walls
            if DEFENSE_ZONE and my_walls_now > 0 and not is_goal(new_state, my_player):
                base -= 1.5

        else:  # Wall
            # Don't allow walls that kill our path
            if my_d_new >= 999:
                return -1e7

            # Early-game wall spam penalty (only if not in defense panic)
            if my_walls_now >= 9 and opp_walls_now >= 9 and not DEFENSE_ZONE:
                base -= 2.0

            # Require wall to slow opponent at least a bit
            if delta_opp <= 0:
                base -= 4.0
            else:
                # Big reward for big slow-down
                if delta_opp >= 3:
                    base += 4.0 * delta_opp
                else:
                    base += 1.5 * delta_opp

            # Punish if we hurt ourselves too much,
            # but be more forgiving in DEFENSE_ZONE (better to survive now).
            if DEFENSE_ZONE:
                if delta_my > 3:
                    base -= 2.0
                elif delta_my > 1:
                    base -= 0.5
            else:
                if delta_my > 2:
                    base -= 3.0
                elif delta_my > 0:
                    base -= 1.0

            # Sprint: walls almost always bad when we are super close,
            # EXCEPT if opponent is in DEFENSE_ZONE (we *must* block).
            if my_dist_now <= 3 and not DEFENSE_ZONE:
                base -= 6.0

            # Backtracking bonus: if opp's first step after this wall goes AWAY from goal
            opp_dist_new_full, opp_path_new = shortest_path_with_route(new_state, opp_player)
            if len(opp_path_new) >= 2:
                (or0, oc0) = opp_path_new[0]
                (or1, oc1) = opp_path_new[1]
                goal_row_opp = 8 if opp_player == '1' else 0

                dist0 = abs(goal_row_opp - or0)
                dist1 = abs(goal_row_opp - or1)
                if dist1 > dist0:
                    # They literally move further from goal on their next step
                    # Boost this even MORE in DEFENSE_ZONE to prioritize "trap then door"
                    base += 5.0
                    if DEFENSE_ZONE:
                        base += 5.0  # extra boost when they're close to winning

            # In DEFENSE_ZONE, extra bonus if we significantly extend their path
            if DEFENSE_ZONE and delta_opp >= 2:
                base += 4.0

        return base

    # ---------- Generate candidate moves ----------

    pawn_moves = game.get_valid_pawn_moves(player=my_player)
    wall_moves: List[List] = []
    if my_walls_now > 0:
        wall_moves = game.get_valid_wall_moves(player=my_player, limit=16)

    candidate_moves: List[List] = pawn_moves + wall_moves

    if not candidate_moves:
        r, c = game.get_my_position()
        return ['M', r, c]

    # ---------- 1-ply scoring of all candidates ----------

    one_ply_data: List[Tuple[List, float, Dict]] = []  # (move, one_ply_score, new_state)

    for move in candidate_moves:
        new_state = game.simulate_move(move)
        s = score_move_one_ply(move, new_state)
        one_ply_data.append((move, s, new_state))

    # Sort best to worst
    one_ply_data.sort(key=lambda x: x[1], reverse=True)

    # ---------- Depth-2 minimax over top-K ----------

    TOP_K_ROOT = min(5, len(one_ply_data))
    CHILD_K_MAX = 4  # prune children by 1-ply score

    def generate_moves_for_player(state_dict: Dict, player: str) -> List[List]:
        """Generate and rank moves for minimax from an arbitrary state."""
        tmp_game = QuoridorGame(json.dumps(state_dict), 'playing', player, player)

        pawn_m = tmp_game.get_valid_pawn_moves(player=player)
        wall_m: List[List] = []
        if state_dict['remaining_walls'][player] > 0:
            limit = 8 if player == my_player else 4
            wall_m = tmp_game.get_valid_wall_moves(player=player, limit=limit)

        moves = pawn_m + wall_m
        if not moves:
            return []

        scored = []
        for m in moves:
            ns = tmp_game.simulate_move(m)
            scored.append((m, base_eval_state(ns)))

        scored.sort(key=lambda x: x[1], reverse=True)
        return [m for m, _ in scored[:CHILD_K_MAX]]

    def minimax(state_dict: Dict, player_to_move: str, depth: int, alpha: float, beta: float) -> float:
        if depth == 0 or is_goal(state_dict, my_player) or is_goal(state_dict, opp_player):
            return base_eval_state(state_dict)

        moves = generate_moves_for_player(state_dict, player_to_move)
        if not moves:
            return base_eval_state(state_dict)

        if player_to_move == my_player:
            value = -1e9
            for m in moves:
                tmp_game = QuoridorGame(json.dumps(state_dict), 'playing', player_to_move, player_to_move)
                ns = tmp_game.simulate_move(m)
                value = max(value, minimax(ns, opp_player, depth - 1, alpha, beta))
                alpha = max(alpha, value)
                if alpha >= beta:
                    break
            return value
        else:  # opponent minimizing our eval
            value = 1e9
            for m in moves:
                tmp_game = QuoridorGame(json.dumps(state_dict), 'playing', player_to_move, player_to_move)
                ns = tmp_game.simulate_move(m)
                value = min(value, minimax(ns, my_player, depth - 1, alpha, beta))
                beta = min(beta, value)
                if beta <= alpha:
                    break
            return value

    depth2_results: List[Tuple[List, float, float]] = []  # (move, combined_score, minimax_score)

    for i in range(TOP_K_ROOT):
        move, s1, new_state = one_ply_data[i]
        mm_score = minimax(new_state, opp_player, depth=1, alpha=-1e9, beta=1e9)
        combined = 0.6 * mm_score + 0.4 * s1
        depth2_results.append((move, combined, mm_score))

    depth2_results.sort(key=lambda x: x[1], reverse=True)

    # ---------- Tiny Monte Carlo tiebreak between top 2 ----------

    def run_small_playout(first_move: List, num_steps: int = 14) -> float:
        """
        Tiny Monte Carlo playout:
        - Only pawn moves,
        - Alternate players,
        - Use base_eval_state at horizon.
        """
        state = deepcopy(state_now)
        current = my_player

        # apply first move
        tmp_game = QuoridorGame(json.dumps(state), 'playing', current, current)
        state = tmp_game.simulate_move(first_move)

        if is_goal(state, my_player):
            return 1.0
        if is_goal(state, opp_player):
            return -1.0

        current = opp_player

        for _ in range(num_steps):
            if is_goal(state, my_player):
                return 1.0
            if is_goal(state, opp_player):
                return -1.0

            sg = QuoridorGame(json.dumps(state), 'playing', current, current)
            pawn_moves = sg.get_valid_pawn_moves(player=current)
            if not pawn_moves:
                break

            # bias slightly toward progress
            best_moves = []
            best_delta = -999
            base_d = game.shortest_path_length(current, state)
            for m in pawn_moves:
                ns = sg.simulate_move(m)
                d_new = game.shortest_path_length(current, ns)
                delta = base_d - d_new
                if delta > best_delta:
                    best_delta = delta
                    best_moves = [m]
                elif delta == best_delta:
                    best_moves.append(m)
            if random.random() < 0.3:
                move = random.choice(pawn_moves)
            else:
                move = random.choice(best_moves)

            state = sg.simulate_move(move)
            current = opp_player if current == my_player else my_player

        e = base_eval_state(state)
        return max(min(e / 40.0, 1.0), -1.0)

    if len(depth2_results) >= 2:
        (m1, s1, _) = depth2_results[0]
        (m2, s2, _) = depth2_results[1]

        if abs(s1 - s2) < 1.5:
            PLAYOUTS = 8
            total1 = 0.0
            total2 = 0.0
            for _ in range(PLAYOUTS):
                total1 += run_small_playout(m1)
                total2 += run_small_playout(m2)
            avg1 = total1 / PLAYOUTS
            avg2 = total2 / PLAYOUTS

            if avg2 > avg1 + 0.05:
                return m2

    best_move = depth2_results[0][0]
    return best_move

# %% [markdown]
# ---
# ## Section 6: Test Your Solver (Optional)
#
# Test parts of your implementation before playing a full game.

# %%
# Create a test state
test_state = {
    'pawns': {'1': [2, 4], '2': [6, 4]},
    'walls': [[3, 3, 'H'], [4, 5, 'V']],
    'remaining_walls': {'1': 8, '2': 9}
}

test_game = QuoridorGame(json.dumps(test_state), 'playing', '1', '1')

print("Test board:")
test_game.print_board()

print(f"Valid pawn moves: {test_game.get_valid_pawn_moves()}")
print(f"My path length: {test_game.shortest_path_length('1')}")
print(f"Opponent path length: {test_game.shortest_path_length('2')}")

# Test your solver
move = my_agent(test_game)
print(f"\nYour solver chose: {move}")
# Out:
# Test board:
#
# =====================================
# Player 1: [2, 4]  Player 2: [6, 4]
# Walls remaining - You: 8, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   · ║ ·   ·   ·
#
# ·   ·   ·   ·   ·   · ║ ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# Valid pawn moves: [['M', 1, 4], ['M', 3, 4], ['M', 2, 3], ['M', 2, 5]]
# My path length: 7
# Opponent path length: 7
#
# Your solver chose: ['M', 2, 5]

# %% [markdown]
# ---
# ## Section 7: Play the Game!
#
# **Run this cell to test your solver against the AI**

# %%
STUDENT_TOKEN = 'DIEGO-OLIVEROS'  # e.g., 'JOHN-DOE'
SOLVER = my_agent
MULTIPLAYER = True
MATCH_ID = None
NUM_GAMES = 3

result = play_game(
    solver=SOLVER,
    base_url=BASE_URL,
    token=STUDENT_TOKEN,
    game_type='quoridor',
    game_class=QuoridorGame,
    multiplayer=MULTIPLAYER,
    match_id=MATCH_ID,
    num_games=NUM_GAMES,
    debug=False,
    verbose=True
)

stats, all_results = result
print("\n📊 Summary:")
print(f"   Record: {stats['wins']}W - {stats['losses']}L - {stats['draws']}D")
print(f"   Win Rate: {stats['win_rate']*100:.1f}%")
# Out:
# 🎮 Creating new match: 3 x quoridor
#    Match ID: 2545
# 🔗 Joining match 2545...
#    You are player: 1
# ⏳ Waiting for opponent to join...
#
# ==================================================
# 🎮 GAME 1/3
# ==================================================
#
#
# =====================================
# Player 1: [0, 4]  Player 2: [8, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [0, 3]  Player 2: [8, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   1   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (7, 4)
#
# =====================================
# Player 1: [0, 3]  Player 2: [7, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   1   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [0, 4]  Player 2: [7, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (6, 4)
#
# =====================================
# Player 1: [0, 4]  Player 2: [6, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [1, 4]  Player 2: [6, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (5, 4)
#
# =====================================
# Player 1: [1, 4]  Player 2: [5, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [2, 4]  Player 2: [5, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (4, 4)
#
# =====================================
# Player 1: [2, 4]  Player 2: [4, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [2, 4]  Player 2: [4, 4]
# Walls remaining - You: 10, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Placing H wall at (7, 2)
#
# =====================================
# Player 1: [2, 4]  Player 2: [4, 4]
# Walls remaining - You: 9, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [3, 4]  Player 2: [4, 4]
# Walls remaining - You: 9, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (4, 3)
#
# =====================================
# Player 1: [3, 4]  Player 2: [4, 3]
# Walls remaining - You: 9, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [3, 3]  Player 2: [4, 3]
# Walls remaining - You: 9, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   1   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (2, 3)
#
# =====================================
# Player 1: [3, 3]  Player 2: [2, 3]
# Walls remaining - You: 9, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   1   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [3, 3]  Player 2: [2, 3]
# Walls remaining - You: 9, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   1   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (2, 4)
#
# =====================================
# Player 1: [3, 3]  Player 2: [2, 4]
# Walls remaining - You: 9, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   1   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [4, 3]  Player 2: [2, 4]
# Walls remaining - You: 9, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   1   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (1, 4)
#
# =====================================
# Player 1: [4, 3]  Player 2: [1, 4]
# Walls remaining - You: 9, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   1   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [4, 4]  Player 2: [1, 4]
# Walls remaining - You: 9, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (0, 4)
#
# =====================================
# Player 1: [4, 4]  Player 2: [1, 4]
# Walls remaining - You: 9, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ========================================
# 🎉 You WON! Congratulations!
#
# 📊 Current Record: 1W - 0L - 0D
#    Games Remaining: 2
#
#
# ==================================================
# 🎮 GAME 2/3
# ==================================================
#
# ℹ️  Player assignment changed: You are now Player 1
#
#
# =====================================
# Player 1: [0, 4]  Player 2: [8, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (1, 4)
#
# =====================================
# Player 1: [1, 4]  Player 2: [8, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [1, 4]  Player 2: [7, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (2, 4)
#
# =====================================
# Player 1: [2, 4]  Player 2: [7, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [2, 4]  Player 2: [6, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Placing H wall at (0, 4)
#
# =====================================
# Player 1: [2, 4]  Player 2: [6, 4]
# Walls remaining - You: 9, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [2, 4]  Player 2: [6, 4]
# Walls remaining - You: 9, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [2, 4]  Player 2: [5, 4]
# Walls remaining - You: 9, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (3, 4)
#
# =====================================
# Player 1: [3, 4]  Player 2: [5, 4]
# Walls remaining - You: 9, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [3, 4]  Player 2: [5, 3]
# Walls remaining - You: 9, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Placing H wall at (4, 2)
#
# =====================================
# Player 1: [3, 4]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [3, 4]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [3, 4]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (3, 5)
#
# =====================================
# Player 1: [3, 5]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 9
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   1   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [3, 5]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   1   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (3, 6)
#
# =====================================
# Player 1: [3, 6]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 8
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   1   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [3, 6]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 7
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   1   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═           ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (3, 7)
#
# =====================================
# Player 1: [3, 7]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 7
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   1   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═           ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [3, 7]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 7
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   1   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═           ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [3, 7]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 6
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   1   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═           ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (4, 7)
#
# =====================================
# Player 1: [4, 7]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 6
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   1   ·
#         ═   ═           ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 7]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 5
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   1   ·
#         ═   ═           ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (4, 6)
#
# =====================================
# Player 1: [4, 6]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 5
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   1   ·   ·
#         ═   ═           ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 6]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 4
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   1   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (4, 5)
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 4
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 3]
# Walls remaining - You: 8, Opponent: 3
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Placing H wall at (2, 0)
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 3]
# Walls remaining - You: 7, Opponent: 3
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   2   ·   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 4]
# Walls remaining - You: 7, Opponent: 3
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Placing H wall at (3, 7)
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 4]
# Walls remaining - You: 6, Opponent: 3
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 4]
# Walls remaining - You: 6, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Placing V wall at (5, 4)
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 4]
# Walls remaining - You: 5, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   2 ║ ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 5]  Player 2: [5, 4]
# Walls remaining - You: 5, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   2 ║ ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 5]  Player 2: [6, 4]
# Walls remaining - You: 5, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#                 ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   2 ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Placing H wall at (0, 2)
#
# =====================================
# Player 1: [4, 5]  Player 2: [6, 4]
# Walls remaining - You: 4, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   2 ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 5]  Player 2: [7, 4]
# Walls remaining - You: 4, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   1   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (4, 6)
#
# =====================================
# Player 1: [4, 6]  Player 2: [7, 4]
# Walls remaining - You: 4, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   ·   1   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 6]  Player 2: [7, 4]
# Walls remaining - You: 4, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   ·   1   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                             ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   2   ·   ·   ·   ·
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [4, 6]  Player 2: [7, 5]
# Walls remaining - You: 4, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ...
# ·   ·   ·   ·   ·   ·   ·   ·   1
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 2)...
#
# =====================================
# Player 1: [7, 8]  Player 2: [5, 8]
# Walls remaining - You: 4, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   2
#                             ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   1
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 1)...
#    Moving pawn to (8, 8)
#
# =====================================
# Player 1: [7, 8]  Player 2: [5, 8]
# Walls remaining - You: 4, Opponent: 2
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#                     ═   ═   ═   ═
# ·   · ║ ·   ·   ·   ·   ·   ·   ·
#         ═   ═   ═   ═   ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   2
#                             ═   ═
# ·   ·   ·   ·   · ║ ·   ·   ·   ·
#                     ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   1
#             ═   ═       ═   ═
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ========================================
# 🎉 You WON! Congratulations!
#
# 📊 Current Record: 2W - 0L - 0D
#    Games Remaining: 1
#
#
# ==================================================
# 🎮 GAME 3/3
# ==================================================
#
# ℹ️  Player assignment changed: You are now Player 2
#
#
# =====================================
# Player 1: [0, 4]  Player 2: [8, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [1, 4]  Player 2: [8, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (7, 4)
#
# =====================================
# Player 1: [1, 4]  Player 2: [7, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [1, 4]  Player 2: [7, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [2, 4]  Player 2: [7, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (6, 4)
#
# =====================================
# Player 1: [2, 4]  Player 2: [6, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [3, 4]  Player 2: [6, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (5, 4)
#
# =====================================
# Player 1: [3, 4]  Player 2: [5, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [4, 4]  Player 2: [5, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (3, 4)
#
# =====================================
# Player 1: [4, 4]  Player 2: [3, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [4, 4]  Player 2: [3, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [5, 4]  Player 2: [3, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (2, 4)
#
# =====================================
# Player 1: [5, 4]  Player 2: [2, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [6, 4]  Player 2: [2, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (1, 4)
#
# =====================================
# Player 1: [6, 4]  Player 2: [1, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ⏳ Waiting for opponent (Player 1)...
#
# =====================================
# Player 1: [7, 4]  Player 2: [1, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# 🤔 Your turn (Player 2)...
#    Moving pawn to (0, 4)
#
# =====================================
# Player 1: [7, 4]  Player 2: [1, 4]
# Walls remaining - You: 10, Opponent: 10
# =====================================
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   2   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
#
# ·   ·   ·   ·   1   ·   ·   ·   ·
#
# ·   ·   ·   ·   ·   ·   ·   ·   ·
# =====================================
#
# ========================================
# 🎉 You WON! Congratulations!
#
# 📊 Current Record: 3W - 0L - 0D
#    Games Remaining: 0
#
#
# 📊 Summary:
#    Record: 3W - 0L - 0D
#    Win Rate: 100.0%
